# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set()

# %config InlineBackend.figure_format = 'svg'

# %%
URL = "https://drive.google.com/file/d/1AmIuxnuKF3Q2K0e-FqY49wa2YXXs9YA/view?usp=sharing"
path = 'https://drive.google.com/uc?export=dowload&id='+URL.split('/')[-2]
df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 URL = "https://drive.google.com/file/d/1AmIuxnuKF3Q2K0e-FqY49wa2YXXs9YA/view?usp=sharing"
#       2 path = 'https://drive.google.com/uc?export=dowload&id='+URL.split('/')[-2]
# ----> 3 df = pd.read_csv(path)
#
# ...

# %%
df.head(2)
